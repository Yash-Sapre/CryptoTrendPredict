# %%
import numpy as np
import pandas as pd
# !pip install yfinance
import yfinance as yf
import matplotlib.pyplot as plt
from array import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from sklearn.preprocessing import StandardScaler


def fetch_data (upto_dates = 240 , tickers='BTC-USD'):
  data = yf.download(tickers=tickers, period = f'{upto_dates}d', interval = '1d')
  new_array = np.array(data.index.to_pydatetime(), dtype=np.datetime64)
  o = data.iloc[: , 0].values
  h = data.iloc[: , 1].values
  l = data.iloc[: , 2].values
  c = data.iloc[: , 3].values
  df= pd.DataFrame(new_array)
  df.columns = ['Date']
  df['Open']=o
  df['High']=h
  df['Low']=l
  df['Close']=c
  return df
# Out:
# WARNING: You are using pip version 21.2.3; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Python\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: yfinance in c:\python\lib\site-packages (0.1.63)
# Requirement already satisfied: lxml>=4.5.1 in c:\python\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: pandas>=0.24 in c:\python\lib\site-packages (from yfinance) (1.3.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\python\lib\site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: requests>=2.20 in c:\python\lib\site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: numpy>=1.15 in c:\python\lib\site-packages (from yfinance) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\python\lib\site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\python\lib\site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\python\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python\lib\site-packages (from requests>=2.20->yfinance) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\python\lib\site-packages (from requests>=2.20->yfinance) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\lib\site-packages (from requests>=2.20->yfinance) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\lib\site-packages (from requests>=2.20->yfinance) (2021.5.30)

# %%
df=fetch_data(200)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date          Open          High           Low         Close
# 0   2021-03-23  54511.660156  55985.441406  53470.695312  54738.945312
# 1   2021-03-24  54710.488281  57262.382812  52514.332031  52774.265625
# 2   2021-03-25  52726.746094  53392.386719  50856.570312  51704.160156
# 3   2021-03-26  51683.011719  55137.312500  51579.855469  55137.312500
# 4   2021-03-27  55137.566406  56568.214844  54242.910156  55973.511719
# ..         ...           ...           ...           ...           ...
# 195 2021-10-04  48208.906250  49456.777344  47045.003906  49112.902344
# 196 2021-10-05  49174.960938  51839.984375  49072.839844  51514.812500
# 197 2021-10-06  51486.664062  55568.464844  50488.191406  55361.449219
# 198 2021-10-07  55338.625000  55338.625000  53525.468750  53805.984375
# 199 2021-10-08  53756.832031  55922.980469  53713.972656  54317.550781
#
# [200 rows x 5 columns]

# %%
cols =['Open']

# %%
df_for_training = df[cols].astype(float)
print(df_for_training.shape)
df_for_training.head(7)
# Out:
# (200, 1)
#            Open
# 0  54511.660156
# 1  54710.488281
# 2  52726.746094
# 3  51683.011719
# 4  55137.566406
# 5  55974.941406
# 6  55947.898438

# %%
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)

# %%
trainX = []
trainY = []
n_past = 10
for i in range(n_past, len(df_for_training_scaled)):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i , 0])   # predict only open for next day

trainX = np.array(trainX)
trainY = np.array(trainY)
print('shape of trainx is :',trainX)
print('shape of trainy is :',trainY)
# Out:
# shape of trainx is : [[[ 1.06516252]
#   [ 1.08747429]
#   [ 0.86486592]
#   ...
#   [ 1.42857221]
#   [ 1.56100376]
#   [ 1.56058689]]
#
#  [[ 1.08747429]
#   [ 0.86486592]
#   [ 0.74774182]
#   ...
#   [ 1.56100376]
#   [ 1.56058689]
#   [ 1.57992362]]
#
#  [[ 0.86486592]
#   [ 0.74774182]
#   [ 1.13539946]
# %%
print(trainX.shape)
print(trainY.shape)
# Out:
# (190, 10, 1)
# (190,)

# %%
model = Sequential()
model.add(LSTM(256, activation='tanh', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(128, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, activation='tanh', return_sequences=True))
model.add(LSTM(64, activation='relu', return_sequences=False))

model.add(Dropout(0.2))

model.add(Dense(32))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 10, 256)           264192
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 10, 128)           197120
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 10, 128)           0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 10, 64)            49408
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 64)                33024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 545,857
# Trainable params: 545,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(trainX, trainY, epochs=100,  validation_split=0.1, verbose=1)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 5s 185ms/step - loss: 0.8180 - val_loss: 0.4165
# Epoch 2/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3756 - val_loss: 0.3912
# Epoch 3/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.3161 - val_loss: 0.3746
# Epoch 4/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2802 - val_loss: 0.5334
# Epoch 5/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2952 - val_loss: 0.4261
# Epoch 6/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2521 - val_loss: 0.3828
# Epoch 7/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.2457 - val_loss: 0.4205
# Epoch 8/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2343 - val_loss: 0.3620
# Epoch 9/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2301 - val_loss: 0.3304
# Epoch 10/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2130 - val_loss: 0.3466
# Epoch 11/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2219 - val_loss: 0.3396
# Epoch 12/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2209 - val_loss: 0.2450
# Epoch 13/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.2023 - val_loss: 0.3137
# Epoch 14/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1806 - val_loss: 0.2681
# Epoch 15/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1579 - val_loss: 0.2541
# Epoch 16/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1522 - val_loss: 0.2738
# Epoch 17/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1738 - val_loss: 0.2258
# Epoch 18/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1441 - val_loss: 0.2751
# Epoch 19/100
# 6/6 [==============================] - ETA: 0s - loss: 0.158 - 0s 35ms/step - loss: 0.1534 - val_loss: 0.2133
# Epoch 20/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.1635 - val_loss: 0.2589
# Epoch 21/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1297 - val_loss: 0.2038
# Epoch 22/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1326 - val_loss: 0.2518
# Epoch 23/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1334 - val_loss: 0.2132
# Epoch 24/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.1306 - val_loss: 0.2180
# Epoch 25/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1239 - val_loss: 0.2081
# Epoch 26/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1236 - val_loss: 0.2135
# Epoch 27/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1088 - val_loss: 0.1919
# Epoch 28/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1113 - val_loss: 0.2105
# Epoch 29/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1198 - val_loss: 0.1742
# Epoch 30/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.1176 - val_loss: 0.1984
# Epoch 31/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1223 - val_loss: 0.1971
# Epoch 32/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.1071 - val_loss: 0.1818
# Epoch 33/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1087 - val_loss: 0.1799
# Epoch 34/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0935 - val_loss: 0.1788
# Epoch 35/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1000 - val_loss: 0.1631
# Epoch 36/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1058 - val_loss: 0.1684
# Epoch 37/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0885 - val_loss: 0.1670
# Epoch 38/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0949 - val_loss: 0.1617
# Epoch 39/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0921 - val_loss: 0.1638
# Epoch 40/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0818 - val_loss: 0.1617
# Epoch 41/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0775 - val_loss: 0.1560
# Epoch 42/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0866 - val_loss: 0.1601
# Epoch 43/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0902 - val_loss: 0.1520
# Epoch 44/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0828 - val_loss: 0.1489
# Epoch 45/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0799 - val_loss: 0.1448
# Epoch 46/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0782 - val_loss: 0.1465
# Epoch 47/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0885 - val_loss: 0.1442
# Epoch 48/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0760 - val_loss: 0.1474
# Epoch 49/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0832 - val_loss: 0.1431
# Epoch 50/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0803 - val_loss: 0.1578
# Epoch 51/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1000 - val_loss: 0.1413
# Epoch 52/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.1026 - val_loss: 0.1403
# Epoch 53/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0860 - val_loss: 0.1562
# Epoch 54/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0799 - val_loss: 0.1384
# Epoch 55/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0737 - val_loss: 0.1410
# Epoch 56/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0712 - val_loss: 0.1443
# Epoch 57/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0755 - val_loss: 0.1333
# Epoch 58/100
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0782 - val_loss: 0.1356
# Epoch 59/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0790 - val_loss: 0.1337
# Epoch 60/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0873 - val_loss: 0.1365
# Epoch 61/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0821 - val_loss: 0.1506
# Epoch 62/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0702 - val_loss: 0.1289
# Epoch 63/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0720 - val_loss: 0.1340
# Epoch 64/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0669 - val_loss: 0.1343
# Epoch 65/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0768 - val_loss: 0.1317
# Epoch 66/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0694 - val_loss: 0.1366
# Epoch 67/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0711 - val_loss: 0.1221
# Epoch 68/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0674 - val_loss: 0.1254
# Epoch 69/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0722 - val_loss: 0.1247
# Epoch 70/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0845 - val_loss: 0.1250
# Epoch 71/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0678 - val_loss: 0.1486
# Epoch 72/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.0747 - val_loss: 0.1242
# Epoch 73/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0580 - val_loss: 0.1290
# Epoch 74/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0572 - val_loss: 0.1205
# Epoch 75/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0757 - val_loss: 0.1230
# Epoch 76/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0604 - val_loss: 0.1287
# Epoch 77/100
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0605 - val_loss: 0.1170
# Epoch 78/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0529 - val_loss: 0.1238
# Epoch 79/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0567 - val_loss: 0.1242
# Epoch 80/100
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0570 - val_loss: 0.1142
# Epoch 81/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0581 - val_loss: 0.1170
# Epoch 82/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0572 - val_loss: 0.1066
# Epoch 83/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0590 - val_loss: 0.1094
# Epoch 84/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0648 - val_loss: 0.1054
# Epoch 85/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0561 - val_loss: 0.1060
# Epoch 86/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0581 - val_loss: 0.1119
# Epoch 87/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0635 - val_loss: 0.1131
# Epoch 88/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0623 - val_loss: 0.1015
# Epoch 89/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0615 - val_loss: 0.1090
# Epoch 90/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0578 - val_loss: 0.1087
# Epoch 91/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0698 - val_loss: 0.1114
# Epoch 92/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0568 - val_loss: 0.1054
# Epoch 93/100
# 6/6 [==============================] - 0s 45ms/step - loss: 0.0661 - val_loss: 0.0977
# Epoch 94/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0647 - val_loss: 0.1070
# Epoch 95/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.0624 - val_loss: 0.1060
# Epoch 96/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0834 - val_loss: 0.1076
# Epoch 97/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0674 - val_loss: 0.1220
# Epoch 98/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0730 - val_loss: 0.1068
# Epoch 99/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0641 - val_loss: 0.1155
# Epoch 100/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.0615 - val_loss: 0.1134

# %%
# Yash's attempt at graph
print(df['Open'])
last_index = len(df['Open'])
new_df = df['Open']
print(10-last_index)
new_df[20-last_index:9-last_index]
type(new_df)
# Out:
# 0      54511.660156
# 1      54710.488281
# 2      52726.746094
# 3      51683.011719
# 4      55137.566406
#            ...
# 195    48208.906250
# 196    49174.960938
# 197    51486.664062
# 198    55338.625000
# 199    53756.832031
# Name: Open, Length: 200, dtype: float64
# -190
# pandas.core.series.Series

# %%
df
# Out:
#           Date          Open          High           Low         Close
# 0   2021-03-23  54511.660156  55985.441406  53470.695312  54738.945312
# 1   2021-03-24  54710.488281  57262.382812  52514.332031  52774.265625
# 2   2021-03-25  52726.746094  53392.386719  50856.570312  51704.160156
# 3   2021-03-26  51683.011719  55137.312500  51579.855469  55137.312500
# 4   2021-03-27  55137.566406  56568.214844  54242.910156  55973.511719
# ..         ...           ...           ...           ...           ...
# 195 2021-10-04  48208.906250  49456.777344  47045.003906  49112.902344
# 196 2021-10-05  49174.960938  51839.984375  49072.839844  51514.812500
# 197 2021-10-06  51486.664062  55568.464844  50488.191406  55361.449219
# 198 2021-10-07  55338.625000  55338.625000  53525.468750  53805.984375
# 199 2021-10-08  53756.832031  55922.980469  53713.972656  54317.550781
#
# [200 rows x 5 columns]

# %%
df=fetch_data(10)
data =df['Open']
data = np.array(data)
data1= data[:10]

input_data =data1
data_scaled = data1.reshape((n_past,1))
data_scaled = scaler.transform(data_scaled).tolist()
out_data = []
i=0
ran = len(data)-10

while(i<ran):
  x_input=data_scaled[len(data_scaled)-n_past:]
  # print(f" for input : {x_input}")
  x_input=np.array(x_input).reshape((1,n_past,1))
  y_pred = model.predict(x_input)[0][0]
  # print(f" Output is : {y_pred}")
  
  out_data.append(scaler.inverse_transform([y_pred])[0])
  data_scaled.append([y_pred])
  i=i+1
print("out_len :",len(out_data))
plt.figure(figsize=(20,10))
plt.plot(np.arange(0,len(data)),data, label='input')
plt.plot(np.arange(10,len(data)),out_data ,label='Prediction')
plt.title(f" Data of hours :{len(data)}")
plt.legend()
# Out:
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   app.launch_new_instance()
# out_len : 223

# %%
# df=fetch_data(10)
# data =df['Open']
# data = np.array(data)
# data1= data[len(data)-n_past:]

# input_data =data1
# data_scaled = data1.reshape((n_past,1))
# data_scaled = scaler.transform(data_scaled).tolist()
# out_data = []
# i=0

# while(i<10):
#   x_input=data_scaled[len(data_scaled)-n_past:]
#   print(f" for input : {x_input}")
#   x_input=np.array(x_input).reshape((1,n_past,1))
#   y_pred = model.predict(x_input)[0][0]
#   print(f" Output is : {y_pred}")
  
#   out_data.append(scaler.inverse_transform([y_pred])[0])
#   data_scaled.append([y_pred])
#   i=i+1
# plt.figure(figsize=(20,10))
# plt.plot(np.arange(0,len(data)),data, label='input')
# plt.plot(np.arange(len(data),len(data)+i),out_data ,label='Prediction')
# plt.title(f" Data of hours :{len(data)}")
# plt.legend()

# %%
len(data)
# Out:
# 233
