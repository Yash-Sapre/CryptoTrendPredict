# %%
import numpy as np
import pandas as pd
# !pip install yfinance
import yfinance as yf
import matplotlib.pyplot as plt
from array import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from sklearn.preprocessing import StandardScaler


def fetch_data (upto_dates = 10 , tickers='BTC-USD'):
  data = yf.download(tickers=tickers, period = f'{upto_dates}d', interval = '1d')
  new_array = np.array(data.index.to_pydatetime(), dtype=np.datetime64)
  o = data.iloc[: , 0].values
  h = data.iloc[: , 1].values
  l = data.iloc[: , 2].values
  c = data.iloc[: , 3].values
  df= pd.DataFrame(new_array)
  df.columns = ['Date']
  df['Open']=o
  df['High']=h
  df['Low']=l
  df['Close']=c
  return df
# Out:
# Requirement already satisfied: yfinance in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (0.1.63)
# Requirement already satisfied: numpy>=1.15 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from yfinance) (1.19.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: requests>=2.20 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from yfinance) (2.25.1)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from yfinance) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.20->yfinance) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\rahul agrawal\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.20->yfinance) (4.0.0)

# %%
df=fetch_data(200)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date          Open          High           Low         Close
# 0   2021-03-24  54710.488281  57262.382812  52514.332031  52774.265625
# 1   2021-03-25  52726.746094  53392.386719  50856.570312  51704.160156
# 2   2021-03-26  51683.011719  55137.312500  51579.855469  55137.312500
# 3   2021-03-27  55137.566406  56568.214844  54242.910156  55973.511719
# 4   2021-03-28  55974.941406  56610.312500  55071.113281  55950.746094
# ..         ...           ...           ...           ...           ...
# 194 2021-10-04  48208.906250  49456.777344  47045.003906  49112.902344
# 195 2021-10-05  49174.960938  51839.984375  49072.839844  51514.812500
# 196 2021-10-06  51486.664062  55568.464844  50488.191406  55361.449219
# 197 2021-10-07  55338.625000  55338.625000  53525.468750  53805.984375
# 198 2021-10-09  53824.000000  54251.089844  53824.000000  54129.195312
#
# [199 rows x 5 columns]

# %%
cols =['Close']

# %%
df_for_training = df[cols].astype(float)
print(df_for_training.shape)
df_for_training.head(7)
# Out:
# (199, 1)
#           Close
# 0  52774.265625
# 1  51704.160156
# 2  55137.312500
# 3  55973.511719
# 4  55950.746094
# 5  57750.199219
# 6  58917.691406

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)

# %%
trainX = []
trainY = []
n_past = 10
for i in range(n_past, len(df_for_training_scaled)):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i , 0])   # predict only open for next day

trainX = np.array(trainX)
trainY = np.array(trainY)
print('shape of trainx is :',trainX.shape)
print('shape of trainy is :',trainY.shape)
# Out:
# shape of trainx is : (189, 10, 1)
# shape of trainy is : (189,)

# %%
model = Sequential()
model.add(LSTM(256, activation='tanh', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(128, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, activation='tanh', return_sequences=True))
model.add(LSTM(64, activation='relu', return_sequences=False))

model.add(Dropout(0.2))

model.add(Dense(32))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 256)           264192
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 128)           197120
# _________________________________________________________________
# dropout (Dropout)            (None, 10, 128)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 64)            49408
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 32)                2080
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 545,857
# Trainable params: 545,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(trainX, trainY, epochs=100,  validation_split=0.1, verbose=1)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 13s 517ms/step - loss: 0.2069 - val_loss: 0.0319
# Epoch 2/100
# 6/6 [==============================] - 0s 55ms/step - loss: 0.0404 - val_loss: 0.0350
# Epoch 3/100
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0301 - val_loss: 0.0249
# Epoch 4/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0240 - val_loss: 0.0275
# Epoch 5/100
# 6/6 [==============================] - 0s 59ms/step - loss: 0.0205 - val_loss: 0.0292
# Epoch 6/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0191 - val_loss: 0.0304
# Epoch 7/100
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0193 - val_loss: 0.0309
# Epoch 8/100
# 6/6 [==============================] - 0s 53ms/step - loss: 0.0223 - val_loss: 0.0308
# Epoch 9/100
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0197 - val_loss: 0.0278
# Epoch 10/100
# 6/6 [==============================] - 0s 60ms/step - loss: 0.0222 - val_loss: 0.0309
# Epoch 11/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0167 - val_loss: 0.0317
# Epoch 12/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0181 - val_loss: 0.0278
# Epoch 13/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0144 - val_loss: 0.0337
# Epoch 14/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0182 - val_loss: 0.0269
# Epoch 15/100
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0194 - val_loss: 0.0319
# Epoch 16/100
# 6/6 [==============================] - 0s 65ms/step - loss: 0.0201 - val_loss: 0.0288
# Epoch 17/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0177 - val_loss: 0.0250
# Epoch 18/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0227 - val_loss: 0.0346
# Epoch 19/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0196 - val_loss: 0.0253
# Epoch 20/100
# 6/6 [==============================] - 0s 45ms/step - loss: 0.0166 - val_loss: 0.0309
# Epoch 21/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0209 - val_loss: 0.0285
# Epoch 22/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0188 - val_loss: 0.0262
# Epoch 23/100
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0169 - val_loss: 0.0295
# Epoch 24/100
# 6/6 [==============================] - 0s 56ms/step - loss: 0.0163 - val_loss: 0.0245
# Epoch 25/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0142 - val_loss: 0.0279
# Epoch 26/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0142 - val_loss: 0.0237
# Epoch 27/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0181 - val_loss: 0.0252
# Epoch 28/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0157 - val_loss: 0.0281
# Epoch 29/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0165 - val_loss: 0.0229
# Epoch 30/100
# 6/6 [==============================] - 0s 53ms/step - loss: 0.0118 - val_loss: 0.0240
# Epoch 31/100
# 6/6 [==============================] - 0s 53ms/step - loss: 0.0132 - val_loss: 0.0224
# Epoch 32/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0140 - val_loss: 0.0207
# Epoch 33/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0128 - val_loss: 0.0190
# Epoch 34/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0117 - val_loss: 0.0195
# Epoch 35/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0131 - val_loss: 0.0191
# Epoch 36/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0096 - val_loss: 0.0182
# Epoch 37/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0127 - val_loss: 0.0205
# Epoch 38/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0131 - val_loss: 0.0171
# Epoch 39/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0137 - val_loss: 0.0188
# Epoch 40/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0123 - val_loss: 0.0222
# Epoch 41/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0127 - val_loss: 0.0173
# Epoch 42/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0106 - val_loss: 0.0174
# Epoch 43/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0092 - val_loss: 0.0194
# Epoch 44/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0109 - val_loss: 0.0167
# Epoch 45/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0113 - val_loss: 0.0164
# Epoch 46/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0101 - val_loss: 0.0198
# Epoch 47/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0112 - val_loss: 0.0154
# Epoch 48/100
# 6/6 [==============================] - 0s 45ms/step - loss: 0.0089 - val_loss: 0.0172
# Epoch 49/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0118 - val_loss: 0.0152
# Epoch 50/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0102 - val_loss: 0.0144
# Epoch 51/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0083 - val_loss: 0.0137
# Epoch 52/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0073 - val_loss: 0.0172
# Epoch 53/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0115 - val_loss: 0.0148
# Epoch 54/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0085 - val_loss: 0.0159
# Epoch 55/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0068 - val_loss: 0.0139
# Epoch 56/100
# 6/6 [==============================] - 0s 45ms/step - loss: 0.0100 - val_loss: 0.0155
# Epoch 57/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0122 - val_loss: 0.0172
# Epoch 58/100
# 6/6 [==============================] - 0s 44ms/step - loss: 0.0089 - val_loss: 0.0147
# Epoch 59/100
# 6/6 [==============================] - 0s 53ms/step - loss: 0.0090 - val_loss: 0.0149
# Epoch 60/100
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0090 - val_loss: 0.0144
# Epoch 61/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0083 - val_loss: 0.0143
# Epoch 62/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0086 - val_loss: 0.0154
# Epoch 63/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0130 - val_loss: 0.0173
# Epoch 64/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0073 - val_loss: 0.0133
# Epoch 65/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0092 - val_loss: 0.0134
# Epoch 66/100
# 6/6 [==============================] - 0s 45ms/step - loss: 0.0110 - val_loss: 0.0168
# Epoch 67/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0082 - val_loss: 0.0132
# Epoch 68/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0088 - val_loss: 0.0157
# Epoch 69/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0081 - val_loss: 0.0128
# Epoch 70/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0088 - val_loss: 0.0147
# Epoch 71/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0081 - val_loss: 0.0130
# Epoch 72/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0081 - val_loss: 0.0152
# Epoch 73/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0078 - val_loss: 0.0123
# Epoch 74/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0090 - val_loss: 0.0133
# Epoch 75/100
# 6/6 [==============================] - 0s 44ms/step - loss: 0.0061 - val_loss: 0.0123
# Epoch 76/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0064 - val_loss: 0.0138
# Epoch 77/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0059 - val_loss: 0.0120
# Epoch 78/100
# 6/6 [==============================] - 0s 45ms/step - loss: 0.0059 - val_loss: 0.0141
# Epoch 79/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0069 - val_loss: 0.0129
# Epoch 80/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0064 - val_loss: 0.0121
# Epoch 81/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0058 - val_loss: 0.0128
# Epoch 82/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0067 - val_loss: 0.0112
# Epoch 83/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0059 - val_loss: 0.0139
# Epoch 84/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0074 - val_loss: 0.0116
# Epoch 85/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0066 - val_loss: 0.0136
# Epoch 86/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0061 - val_loss: 0.0115
# Epoch 87/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0082 - val_loss: 0.0114
# Epoch 88/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0064 - val_loss: 0.0138
# Epoch 89/100
# 6/6 [==============================] - 0s 48ms/step - loss: 0.0055 - val_loss: 0.0113
# Epoch 90/100
# 6/6 [==============================] - 0s 44ms/step - loss: 0.0069 - val_loss: 0.0128
# Epoch 91/100
# 6/6 [==============================] - 0s 47ms/step - loss: 0.0058 - val_loss: 0.0109
# Epoch 92/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0065 - val_loss: 0.0110
# Epoch 93/100
# 6/6 [==============================] - 0s 53ms/step - loss: 0.0058 - val_loss: 0.0131
# Epoch 94/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0055 - val_loss: 0.0115
# Epoch 95/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0064 - val_loss: 0.0110
# Epoch 96/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.0060 - val_loss: 0.0105
# Epoch 97/100
# 6/6 [==============================] - 0s 50ms/step - loss: 0.0063 - val_loss: 0.0131
# Epoch 98/100
# 6/6 [==============================] - 0s 46ms/step - loss: 0.0072 - val_loss: 0.0109
# Epoch 99/100
# 6/6 [==============================] - 0s 49ms/step - loss: 0.0059 - val_loss: 0.0112
# Epoch 100/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.0048 - val_loss: 0.0111

# %%
df=fetch_data(10)
data =df['Close']
data = np.array(data)
print(data)
data1= data[:10]

input_data =data1
data_scaled = data1.reshape((n_past,1))
data_scaled = scaler.transform(data_scaled).tolist()
out_data = []
i=0
ran = len(data)-10

while(i<ran):
  x_input=data_scaled[len(data_scaled)-n_past:]
  # print(f" for input : {x_input}")
  x_input=np.array(x_input).reshape((1,n_past,1))
  y_pred = model.predict(x_input)[0][0]
  # print(f" Output is : {y_pred}")
  
  out_data.append(scaler.inverse_transform([y_pred])[0])
  data_scaled.append([y_pred])
  i=i+1
print("out_len :",len(out_data))
plt.figure(figsize=(20,10))
plt.plot(np.arange(0,len(data)),data, label='input')
plt.plot(np.arange(10,len(data)),out_data ,label='Prediction')
plt.title(f" Data of hours :{len(data)}")
plt.legend()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [43790.89453125 48116.94140625 47711.48828125 48199.953125
#  49112.90234375 51514.8125     55361.44921875 53805.984375
#  54105.1328125 ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c6240be7448b> in <module>
#       6
#       7 input_data =data1
# ----> 8 data_scaled = data1.reshape((n_past,1))
#       9 data_scaled = scaler.transform(data_scaled).tolist()
#      10 out_data = []
#
# ValueError: cannot reshape array of size 9 into shape (10,1)

# %%
# df=fetch_data(10)
# data =df['Open']
# data = np.array(data)
# data1= data[len(data)-n_past:]

# input_data =data1
# data_scaled = data1.reshape((n_past,1))
# data_scaled = scaler.transform(data_scaled).tolist()
# out_data = []
# i=0

# while(i<10):
#   x_input=data_scaled[len(data_scaled)-n_past:]
#   print(f" for input : {x_input}")
#   x_input=np.array(x_input).reshape((1,n_past,1))
#   y_pred = model.predict(x_input)[0][0]
#   print(f" Output is : {y_pred}")
  
#   out_data.append(scaler.inverse_transform([y_pred])[0])
#   data_scaled.append([y_pred])
#   i=i+1
# plt.figure(figsize=(20,10))
# plt.plot(np.arange(0,len(data)),data, label='input')
# plt.plot(np.arange(len(data),len(data)+i),out_data ,label='Prediction')
# plt.title(f" Data of hours :{len(data)}")
# plt.legend()

# %%
len(data)
